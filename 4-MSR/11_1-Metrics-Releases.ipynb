# %% [markdown]
# ### Populates Table Metrics Period
#
# Metrics Period:
# * 1 record per month/week
# * Get analysis_init month and year
# * Fill 12 consecutive months
#
# ## Summarize metrics by period
#
# * Commit Size
# * Test Volume
# * Merge Conflicts
# * Communication
# * Bugs
# * Bugs Ratio
# * Age

# %% [markdown]
# ### Fill the table Metric Release:

# %%
repos = getProjectsReleases()
#select P.repo_name,P.analysis_init,P.analysis_finish,R.NODE_ID,R.created_at,P.ci,P.created

for repo in repos:    
    project = repo[0]
    analysisInit = repo[1]  
    analysisFinish = repo[2]  
    release = repo[3]  
    release_creation = repo[4]  
    ci = repo[5]  
    repo_creation = repo[6]
    
    #saveReleaseMetrics(project,ci,release,release_creation,repo_creation)
    updateReleaseMetrics(project,ci,release,release_creation,repo_creation)
# Out:
# Project: agershun/alasql		 Release: MDc6UmVsZWFzZTg3NTE5NzQ=
# Conflitos: 0
# aqui 1: 0 - agershun/alasql - MDc6UmVsZWFzZTg3NTE5NzQ=
# aqui 2
# aqui 3
# Project: agershun/alasql		 Release: MDc6UmVsZWFzZTkzNTcyMTA=
# Conflitos: 0
# aqui 1: 0 - agershun/alasql - MDc6UmVsZWFzZTkzNTcyMTA=
# aqui 2
# aqui 3
# Project: agershun/alasql		 Release: MDc6UmVsZWFzZTExNDkxNTEy
# Conflitos: 0
# aqui 1: 0 - agershun/alasql - MDc6UmVsZWFzZTExNDkxNTEy
# aqui 2
# aqui 3
# Project: agershun/alasql		 Release: MDc6UmVsZWFzZTExOTI0NDE5
# Conflitos: 0
# aqui 1: 0 - agershun/alasql - MDc6UmVsZWFzZTExOTI0NDE5
# aqui 2
# aqui 3
# Project: agershun/alasql		 Release: MDc6UmVsZWFzZTExOTMwNzYz
# Conflitos: 0
# aqui 1: 0 - agershun/alasql - MDc6UmVsZWFzZTExOTMwNzYz
# aqui 2
# aqui 3
# Project: agershun/alasql		 Release: MDc6UmVsZWFzZTEyMjYxMjE4
# Conflitos: 0
# aqui 1: 0 - agershun/alasql - MDc6UmVsZWFzZTEyMjYxMjE4
# aqui 2
# aqui 3
# Project: agershun/alasql		 Release: MDc6UmVsZWFzZTEyNzI3NjAz
# Conflitos: 0
# aqui 1: 0 - agershun/alasql - MDc6UmVsZWFzZTEyNzI3NjAz
# aqui 2
# aqui 3
# Project: agershun/alasql		 Release: MDc6UmVsZWFzZTEyNzQ3NDQx
# Conflitos: 0
# aqui 1: 0 - agershun/alasql - MDc6UmVsZWFzZTEyNzQ3NDQx
# aqui 2
# aqui 3
# Project: amark/gun		 Release: MDc6UmVsZWFzZTE0OTk2MzAw
# Conflitos: 0
# aqui 1: 0 - amark/gun - MDc6UmVsZWFzZTE0OTk2MzAw
# aqui 2
# aqui 3
# Project: amphp/http-server		 Release: MDc6UmVsZWFzZTEwMjIzMzYx
# Conflitos: 0
# aqui 1: 0 - amphp/http-server - MDc6UmVsZWFzZTEwMjIzMzYx
# aqui 2
# aqui 3
# Project: amphp/http-server		 Release: MDc6UmVsZWFzZTEwMjQ5MTUw
# Conflitos: 0
# aqui 3
# Project: apollographql/react-apollo		 Release: MDc6UmVsZWFzZTEzMTQ4MDkx
# Conflitos: 0
# aqui 1: 0 - apollographql/react-apollo - MDc6UmVsZWFzZTEzMTQ4MDkx
# aqui 2
# aqui 3
# Project: apollographql/react-apollo		 Release: MDc6UmVsZWFzZTEzMTY4NTE2
# Conflitos: 0
# aqui 1: 0 - apollographql/react-apollo - MDc6UmVsZWFzZTEzMTY4NTE2
# aqui 2
# aqui 3
# Project: apollographql/react-apollo		 Release: MDc6UmVsZWFzZTEzMTk4NjUw
# Conflitos: 0
# aqui 1: 0 - apollographql/react-apollo - MDc6UmVsZWFzZTEzMTk4NjUw
# aqui 2
# aqui 3
# Project: apollographql/react-apollo		 Release: MDc6UmVsZWFzZTE1MTY2Nzc1
# Conflitos: 0
# aqui 1: 0 - apollographql/react-apollo - MDc6UmVsZWFzZTE1MTY2Nzc1
# aqui 2
# aqui 3
# Project: apollographql/react-apollo		 Release: MDc6UmVsZWFzZTE1ODIxODc5
# Conflitos: 0
# aqui 1: 0 - apollographql/react-apollo - MDc6UmVsZWFzZTE1ODIxODc5
# aqui 2
# aqui 3
# Project: apollographql/react-apollo		 Release: MDc6UmVsZWFzZTE1ODIxODg5
# Conflitos: 0
# aqui 1: 0 - apollographql/react-apollo - MDc6UmVsZWFzZTE1ODIxODg5
# aqui 2
# aqui 3
# Project: apollographql/react-apollo		 Release: MDc6UmVsZWFzZTE2MzE0MTMx
# Conflitos: 0
# aqui 1: 0 - apollographql/react-apollo - MDc6UmVsZWFzZTE2MzE0MTMx
# aqui 2
# aqui 3
# Project: appium/appium		 Release: MDc6UmVsZWFzZTIyNDM1ODI2
# Conflitos: 0
# aqui 1: 0 - appium/appium - MDc6UmVsZWFzZTIyNDM1ODI2
# aqui 2
# aqui 3
# Project: appium/appium		 Release: MDc6UmVsZWFzZTI0NTMyMjky
# Conflitos: 0
# aqui 1: 0 - appium/appium - MDc6UmVsZWFzZTI0NTMyMjky
# aqui 2
# aqui 3
# Project: appium/appium		 Release: MDc6UmVsZWFzZTI2MTUzOTUw
# Conflitos: 0
# aqui 1: 0 - appium/appium - MDc6UmVsZWFzZTI2MTUzOTUw
# aqui 2
# aqui 3
# Project: appium/appium		 Release: MDc6UmVsZWFzZTI4NzYxMDcz
# Conflitos: 0
# aqui 1: 0 - appium/appium - MDc6UmVsZWFzZTI4NzYxMDcz
# aqui 2
# aqui 3
# Project: appium/appium		 Release: MDc6UmVsZWFzZTI5ODk1MDM0
# Conflitos: 0
# aqui 1: 0 - appium/appium - MDc6UmVsZWFzZTI5ODk1MDM0
# aqui 2
# aqui 3
# Project: appium/appium		 Release: MDc6UmVsZWFzZTMxNTgzMjg4
# Conflitos: 0
# aqui 1: 0 - appium/appium - MDc6UmVsZWFzZTMxNTgzMjg4
# aqui 2
# aqui 3
# Project: appium/appium		 Release: MDc6UmVsZWFzZTMzMTIxMjk2
# Conflitos: 0
# aqui 1: 0 - appium/appium - MDc6UmVsZWFzZTMzMTIxMjk2
# aqui 2
# Project: BijoySingh/Scarlet-Notes		 Release: MDc6UmVsZWFzZTkwNjQ5MDY=
# Conflitos: 0
# aqui 1: 0 - BijoySingh/Scarlet-Notes - MDc6UmVsZWFzZTkwNjQ5MDY=
# aqui 2
# aqui 3
# Project: biojava/biojava		 Release: MDc6UmVsZWFzZTE5ODIyMjU3
# Conflitos: 0
# aqui 1: 0 - biojava/biojava - MDc6UmVsZWFzZTE5ODIyMjU3
# aqui 2
# aqui 3
# Project: biojava/biojava		 Release: MDc6UmVsZWFzZTI4MDExMjA3
# Conflitos: 0
# aqui 1: 0 - biojava/biojava - MDc6UmVsZWFzZTI4MDExMjA3
# aqui 2
# aqui 3
# Project: bytefury/crater		 Release: MDc6UmVsZWFzZTI3MTMwNDEw
# Conflitos: 0
# aqui 1: 0 - bytefury/crater - MDc6UmVsZWFzZTI3MTMwNDEw
# aqui 2
# aqui 3
# Project: bytefury/crater		 Release: MDc6UmVsZWFzZTM0NzY3MTI3
# Conflitos: 0
# aqui 1: 0 - bytefury/crater - MDc6UmVsZWFzZTM0NzY3MTI3
# aqui 2
# aqui 3
# Project: bytefury/crater		 Release: MDc6UmVsZWFzZTM1MDMyMTAz
# Conflitos: 0
# aqui 1: 0 - bytefury/crater - MDc6UmVsZWFzZTM1MDMyMTAz
# aqui 2
# aqui 3
# Project: bytefury/crater		 Release: MDc6UmVsZWFzZTM1NjQ1ODMy
# Conflitos: 0
# aqui 1: 0 - bytefury/crater - MDc6UmVsZWFzZTM1NjQ1ODMy
# aqui 2
# aqui 3
# Project: bytefury/crater		 Release: MDc6UmVsZWFzZTM1ODY4MjI0
# Conflitos: 0
# aqui 1: 0 - bytefury/crater - MDc6UmVsZWFzZTM1ODY4MjI0
# aqui 2
# aqui 3
# Project: bytefury/crater		 Release: MDc6UmVsZWFzZTM2NzU3NTc2
# Conflitos: 0
# aqui 1: 0 - bytefury/crater - MDc6UmVsZWFzZTM2NzU3NTc2
# aqui 2
# aqui 3
# Project: bytefury/crater		 Release: MDc6UmVsZWFzZTQyNTI2NTI1
# Conflitos: 0
# aqui 1: 0 - bytefury/crater - MDc6UmVsZWFzZTQyNTI2NTI1
# aqui 2
# aqui 3
# Project: bytefury/crater		 Release: MDc6UmVsZWFzZTQ1MTUyOTkw
# Conflitos: 0
# aqui 1: 0 - bytefury/crater - MDc6UmVsZWFzZTQ1MTUyOTkw
# aqui 2
# aqui 3
# Project: CalebFenton/simplify		 Release: MDc6UmVsZWFzZTcyMTgyODc=
# Conflitos: 0
# aqui 1: 0 - CalebFenton/simplify - MDc6UmVsZWFzZTcyMTgyODc=
# aqui 2
# aqui 3
# Project: celzero/rethink-app		 Release: MDc6UmVsZWFzZTM5MzgxOTI4
# Conflitos: 0
# aqui 1: 0 - celzero/rethink-app - MDc6UmVsZWFzZTM5MzgxOTI4
# aqui 2
# aqui 3
# Project: celzero/rethink-app		 Release: MDc6UmVsZWFzZTM5OTUzMTc0
# Conflitos: 0
# aqui 1: 0 - celzero/rethink-app - MDc6UmVsZWFzZTM5OTUzMTc0
# aqui 2
# aqui 3
# Project: celzero/rethink-app		 Release: MDc6UmVsZWFzZTQwODgwMjYz
# Conflitos: 0
# aqui 1: 0 - celzero/rethink-app - MDc6UmVsZWFzZTQwODgwMjYz
# aqui 2
# aqui 3
# Project: celzero/rethink-app		 Release: MDc6UmVsZWFzZTQxNDgyMTky
# Conflitos: 0
# aqui 1: 0 - celzero/rethink-app - MDc6UmVsZWFzZTQxNDgyMTky
# aqui 2
# aqui 3
# Project: celzero/rethink-app		 Release: RE_kwDOECJNms4C-vsi
# Conflitos: 0
# aqui 1: 0 - celzero/rethink-app - RE_kwDOECJNms4C-vsi
# aqui 2
# aqui 3
# Project: celzero/rethink-app		 Release: RE_kwDOECJNms4DMmyc
# Conflitos: 0
# aqui 1: 0 - celzero/rethink-app - RE_kwDOECJNms4DMmyc
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTIwOTY5NjQ0
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTIwOTY5NjQ0
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTIwOTY5NTY2
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTIwOTY5NTY2
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTIxOTgzOTEw
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTIxOTgzOTEw
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTIxOTg0MDc3
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTIxOTg0MDc3
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTIyODgzNjcz
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTIyODgzNjcz
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTIyODgzODYx
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTIyODgzODYx
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTIzNjY4OTg3
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTIzNjY4OTg3
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTI1Nzk4Mjcz
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTI1Nzk4Mjcz
# aqui 2
# aqui 3
# Project: chainer/chainer		 Release: MDc6UmVsZWFzZTI5MTAxOTMy
# Conflitos: 0
# aqui 1: 0 - chainer/chainer - MDc6UmVsZWFzZTI5MTAxOTMy
# aqui 2
# aqui 3
# Project: cleanflight/cleanflight		 Release: MDc6UmVsZWFzZTU1NzMxOTE=
# Conflitos: 0
# aqui 1: 0 - cleanflight/cleanflight - MDc6UmVsZWFzZTU1NzMxOTE=
# aqui 2
# aqui 3
# Project: cleanflight/cleanflight		 Release: MDc6UmVsZWFzZTU5NDk2NDI=
# Conflitos: 0
# aqui 1: 0 - cleanflight/cleanflight - MDc6UmVsZWFzZTU5NDk2NDI=
# aqui 2
# aqui 3
# Project: cleanflight/cleanflight		 Release: MDc6UmVsZWFzZTYwNjY1NzQ=
# Conflitos: 0
# aqui 1: 0 - cleanflight/cleanflight - MDc6UmVsZWFzZTYwNjY1NzQ=
# aqui 2
# aqui 3
# Project: cleanflight/cleanflight		 Release: MDc6UmVsZWFzZTYxMTQ4NzA=
# Conflitos: 0
# aqui 1: 0 - cleanflight/cleanflight - MDc6UmVsZWFzZTYxMTQ4NzA=
# aqui 2
# aqui 3
# Project: cleanflight/cleanflight		 Release: MDc6UmVsZWFzZTYxNTUyOTQ=
# Conflitos: 0
# aqui 1: 0 - cleanflight/cleanflight - MDc6UmVsZWFzZTYxNTUyOTQ=
# aqui 2
# aqui 3
# Project: cleanflight/cleanflight		 Release: MDc6UmVsZWFzZTY3Nzc5NTM=
# Conflitos: 0
# aqui 1: 0 - cleanflight/cleanflight - MDc6UmVsZWFzZTY3Nzc5NTM=
# aqui 2
# aqui 3
# Project: cleanflight/cleanflight		 Release: MDc6UmVsZWFzZ
# Conflitos: 0
# aqui 1: 0 - xtermjs/xterm.js - MDc6UmVsZWFzZTE3NjkzMzY5
# aqui 2
# aqui 3
# Project: xtermjs/xterm.js		 Release: MDc6UmVsZWFzZTE3NzEwNTI2
# Conflitos: 0
# aqui 1: 0 - xtermjs/xterm.js - MDc6UmVsZWFzZTE3NzEwNTI2
# aqui 2
# aqui 3
# Project: yabwe/medium-editor		 Release: MDc6UmVsZWFzZTM4NjM5NTI=
# Conflitos: 0
# aqui 1: 0 - yabwe/medium-editor - MDc6UmVsZWFzZTM4NjM5NTI=
# aqui 2
# aqui 3
# Project: yabwe/medium-editor		 Release: MDc6UmVsZWFzZTQwNDQ0MTY=
# Conflitos: 0
# aqui 1: 0 - yabwe/medium-editor - MDc6UmVsZWFzZTQwNDQ0MTY=
# aqui 2
# aqui 3
# Project: yabwe/medium-editor		 Release: MDc6UmVsZWFzZTQyNjA3MjU=
# Conflitos: 0
# aqui 1: 0 - yabwe/medium-editor - MDc6UmVsZWFzZTQyNjA3MjU=
# aqui 2
# aqui 3
# Project: yabwe/medium-editor		 Release: MDc6UmVsZWFzZTUyMDg3MDE=
# Conflitos: 0
# aqui 1: 0 - yabwe/medium-editor - MDc6UmVsZWFzZTUyMDg3MDE=
# aqui 2
# aqui 3
# Project: yabwe/medium-editor		 Release: MDc6UmVsZWFzZTU2MTc0MDk=
# Conflitos: 0
# aqui 1: 0 - yabwe/medium-editor - MDc6UmVsZWFzZTU2MTc0MDk=
# aqui 2
# aqui 3
# Project: yabwe/medium-editor		 Release: MDc6UmVsZWFzZTY4NTIzMTY=
# Conflitos: 0
# aqui 1: 0 - yabwe/medium-editor - MDc6UmVsZWFzZTY4NTIzMTY=
# aqui 2
# aqui 3
# Project: yzhao062/pyod		 Release: MDc6UmVsZWFzZTIyMzYyMDgx
# Conflitos: 0
# aqui 1: 0 - yzhao062/pyod - MDc6UmVsZWFzZTIyMzYyMDgx
# aqui 2
# aqui 3
# Project: yzhao062/pyod		 Release: MDc6UmVsZWFzZTI0NjEzMzE0
# Conflitos: 0
# aqui 1: 0 - yzhao062/pyod - MDc6UmVsZWFzZTI0NjEzMzE0
# aqui 2
# aqui 3
# Project: yzhao062/pyod		 Release: MDc6UmVsZWFzZTI2MTU4NDY0
# Conflitos: 0
# aqui 1: 0 - yzhao062/pyod - MDc6UmVsZWFzZTI2MTU4NDY0
# aqui 2
# aqui 3
# Project: yzhao062/pyod		 Release: MDc6UmVsZWFzZTI4MTMzODM4
# Conflitos: 0
# aqui 1: 0 - yzhao062/pyod - MDc6UmVsZWFzZTI4MTMzODM4
# aqui 2
# aqui 3
# Project: yzhao062/pyod		 Release: MDc6UmVsZWFzZTMxNTY3MzYx
# Conflitos: 0
# aqui 1: 0 - yzhao062/pyod - MDc6UmVsZWFzZTMxNTY3MzYx
# aqui 2
# aqui 3
# Project: yzhao062/pyod		 Release: MDc6UmVsZWFzZTM0MDY5ODgw
# Conflitos: 0
# aqui 1: 0 - yzhao062/pyod - MDc6UmVsZWFzZTM0MDY5ODgw
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI0MzEzMjYy
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI0MzEzMjYy
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI0MzIxOTk5
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI0MzIxOTk5
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI1NjQ5OTc0
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI1NjQ5OTc0
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI1NjgyODkw
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI1NjgyODkw
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI2MTQyMDQ3
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI2MTQyMDQ3
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI2NDY4ODQy
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI2NDY4ODQy
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI2ODM2MjQw
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI2ODM2MjQw
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI5NzcwMjc0
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI5NzcwMjc0
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTI5ODE1MDA1
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTI5ODE1MDA1
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTM3MTgzOTc4
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTM3MTgzOTc4
# aqui 2
# aqui 3
# Project: zhaojun1998/zfile		 Release: MDc6UmVsZWFzZTM5NTkyNjY3
# Conflitos: 0
# aqui 1: 0 - zhaojun1998/zfile - MDc6UmVsZWFzZTM5NTkyNjY3
# aqui 2
# aqui 3

# %%
release
# Out:
# 'MDc6UmVsZWFzZTM4MTY4NTEw'

# %% [markdown]
# ### Fill the table Metric Release with metrics
# * Commit Size, Test Volume, Merge Conflicts, Communication, Bugs

# %%
def saveReleaseMetrics(project,ci,release,release_creation,repo_creation):
    print('Project: {}\t\t Release: {}'.format(project,release))
    
    prs = getPrs(project,release)
    if len(prs) == 0:
        print('\t\t\t saiu no len(prs)')
        return
    
    bugs = getBugs(project,release)
    bugs = int(bugs['bugs'][0])
    issues = getIssues(project,release)
    issues = int(issues['issues'][0])
    
    if issues == 0:
        bugs_ratio = 0
    else:
        bugs_ratio = bugs/issues
        
    print(f'\t\t issues: {issues} - bugs: {bugs} - bugs_ratio: {bugs_ratio}')
    
    age = abs(release_creation - repo_creation).days
    communication = getCommunication(project,release)
    conflicts = getMergeConflicts(project,release)
    conflictsGit = getMergeConflictsGit(project,release)
    frequency_authors = getFrequencyAuthors(project,release)
    
    builds = getBuilds(project, release)
    commits = sum(map(lambda x: int(x), prs['commits'].tolist())) 
    
    #test_proportion ou test_volume
    try:
        test_vol = prs['test_volume'].sum()
        commit_size = prs['commit_size'].sum()
        if test_vol == 0:
            test_vol_proportional = 0
        else:
            test_vol_proportional = (test_vol/commit_size)
    except Exception as e:
        test_vol_proportional = 0
        
    #print(f'\t\t test_vol_prop: {test_vol_proportional} - test_vol: {test_vol} - commit_size: {commit_size}')
    #print('\t\t Communication mean: {} - communication median: {} - merge conflicts: {}'.format(communication['communication'].mean(),communication['communication'].median(),conflicts['conflicts'][0]))
    #print(f'\t\t bugs: {bugs} - builds: {len(builds)} - commits: {commits}')
    #print(f'\t\t age: {age} - bugs_ratio: {bugs_ratio}\n')   
                        #repo_name,release,ci,qtdPR, commit_size_mean,         commit_size_median,         commit_size_perfile_mean,            commit_size_perfile_median,           test_volume_mean,                                 test_volume_median,                         communication_mean,                   communication_median,                                                                                                                                       merge_conflicts,      bugs,  qtybuilds, commits,test_vol_proportional,age,bugs_ratio):   
    insertMetricsRelease(project,release,release_creation,ci,len(prs),prs['commit_size'].mean(),prs['commit_size'].median(),prs['commit_size_per_file'].mean(),prs['commit_size_per_file'].median(),(prs['test_volume']/prs['commit_size']).mean(),(prs['test_volume']/prs['commit_size']).median(),communication['communication'].mean(),communication['communication'].median(),frequency_authors['author_frequency'].mean(),frequency_authors['author_frequency'].median(),int(conflicts['conflicts'][0]),int(conflictsGit['conflicts'][0]),bugs, len(builds),commits,test_vol_proportional,age,bugs_ratio)

# %%
def updateReleaseMetrics(project,ci,release,release_creation,repo_creation):
    print('Project: {}\t\t Release: {}'.format(project,release))
    
    conflictsGit = int(getMergeConflictsGit2(project,release)['conflicts'][0])
    print(f'Conflitos: {conflictsGit}')
    updateMetricsRelease(project,release,conflictsGit)

# %%
def updateMetricsRelease(repo_name,release,merge_conflictsGit):
    try:
        query = """UPDATE METRICS_RELEASES
                    SET merge_conflicts_gitv2 = %s
                WHERE repo_name like %s and release_id like %s;"""

        
        connection = connectDB()
        cursor = connection.cursor()
        cursor.execute(query, [merge_conflictsGit,repo_name,release])
        connection.commit()
        connection.close()
    except psycopg2.IntegrityError as e:
        print ("==============================================================")
        print ("Error while updating into PostgreSQL. insertMetricsRelease >>> Exception: {}".format(e)) 
        print('Project: {}    Release - {}'.format(repo_name,release))
        connection.close()
    except Exception as e:
        print ("==============================================================")
        print ("Error while processing insertMetricsRelease >>> Exception: {}".format(e)) 
        print('Project: {}    Release - {}'.format(repo_name,release))

# %% [markdown]
# ### Aux Functions

# %%
import psycopg2
import os
import requests 
import time
import pytz    
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import pandas as pd
from scipy import stats
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
from sqlalchemy.engine import URL
from sqlalchemy import create_engine

# %%
def connectDB():
    f = open('/home/psql_pwd.txt', "r")
    pwd = f.readline().replace('\n','')
    
    return psycopg2.connect(user = "ci_quality",
                              password = pwd,
                              host = "127.0.0.1",
                              port = "5432",
                              database = "Causal_CI_Quality_v4")

# %%
def connectDBPandas():
    f = open('/home/psql_pwd.txt', "r")
    pwd = f.readline().replace('\n','')
    DATABASE_URI = 'postgresql://ci_quality:{}@localhost:5432/Causal_CI_Quality_v4'.format(pwd)
    
    return create_engine(DATABASE_URI)

# %%
def getProjectsReleases():    
    query = """select P.repo_name,P.analysis_init,P.analysis_finish,R.NODE_ID,R.created_at,P.ci,P.created
                from projects P INNER JOIN project_releases R ON P.repo_name = R.repo_name
                WHERE P.RQ1_INCLUDED IS TRUE and R.created_at BETWEEN P.analysis_init AND P.analysis_finish

                and P.repo_name NOT IN (select distinct repo_name from metrics_releases)
                
                ORDER BY P.repo_name,R.CREATED_AT asc;"""
    

    connection = connectDB()
    cursor = connection.cursor()
    cursor.execute(query)
    result = cursor.fetchall()
    connection.close()
    return result

# %%
def getProjectPeriods():
    query = """select repo_name, init_period, end_period from METRICS_PERIOD
    WHERE PERIOD iLIKE 'MONTH' 
    --and before_ci is true
    --and repo_name IN ( select repo_name from projects where rq1 is true)
    order by repo_name,period,init_period"""

    connection = connectDB()
    cursor = connection.cursor()
    cursor.execute(query)
    result = cursor.fetchall()
    connection.close()
    return result

# %%
def insertPeriod(project,init_period,end_period,order,metric,beforeCI,ci):
    connection = connectDB()
    try:
        query = """INSERT INTO metrics_period (repo_name,init_period,end_period,order_period,period,before_ci,ci) 
        VALUES("""+'%s,'*6+'%s);'

        cursor = connection.cursor()
        cursor.execute(query,[project,init_period,end_period,order,metric,beforeCI,ci])

        connection.commit()
        #print('INSERT INTO metrics_period (repo_name,init_period,end_period,order_period,period) VALUES({},{},{},{},{})'.format(project,init_period,end_period,order,metric))
    except Exception as e:
        print ("Error while inserting into PostgreSQL. insertPeriod >>> Repository: {}, init: {}, finish: {}".format(repo, init_period,end_period)) 
        print(e)
    finally:
        connection.close()

# %%
def getPrs(project_name,release):
    connection = connectDBPandas()
    query = """select commit_size,(commit_size/files) commit_size_per_file,(test_volume/commit_size) TEST_PROPORTION,test_volume,commits 
                from pullrequests 
                WHERE release_id like %s AND project_name ilike %s AND commit_size is not null AND commit_size >0;"""

    df = pd.read_sql_query(query,con=connection,params=[release,project_name])
    connection.dispose()
    return df
    #Check if column contains all values 0. In this case we do not filter outliers.
    #if checkValues(df['commit_size']) and checkValues(df['test_volume']):
    #    return df
    #else:
    #    return removeOutliers(df)
    #return df

# %%
def getCommunication(project_name,release):
    connection = connectDBPandas()
    query = """select ("Comments"+review_comments) COMMUNICATION 
                from pullrequests WHERE release_id like %s AND project_name ilike %s AND ("Comments" is not null or review_comments is not null);"""

    df = pd.read_sql_query(query,con=connection,params=[release,project_name])
    connection.dispose()
    return df
    #Check if column contains all values 0. In this case we do not filter outliers.
    #if checkValues(df['communication']):
    #    return df
    #else:
    #    return removeOutliers(df)

# %%
def getFrequencyAuthors(project_name,release):
    connection = connectDBPandas()
    query = """select author_frequency
                from pullrequests WHERE release_id like %s AND project_name ilike %s;"""

    df = pd.read_sql_query(query,con=connection,params=[release,project_name])
    connection.dispose()
    return df

# %%
def getMergeConflicts(project_name,release):
    connection = connectDBPandas()
    query = """select count(id) conflicts from PULLREQUESTS 
    where project_name ilike %s AND release_id like %s AND mergeconflict is True"""

    df = pd.read_sql_query(query,con=connection,params=[project_name,release])
    connection.dispose()
    return df

# %%
def getMergeConflictsGit(project_name,release):
    connection = connectDBPandas()
    query = """select count(repo_name) conflicts from MERGE_CONFLICT 
    where repo_name ilike %s AND release_id like %s;"""

    df = pd.read_sql_query(query,con=connection,params=[project_name,release])
    connection.dispose()
    return df

# %%
project_name = 'agershun/alasql'
release = 'ebc36cacee1695ace02c1f8e5b742d9e80234cd8'
res = getMergeConflictsGit2(project_name,release)
print(res['conflicts'][0])
# Out:
# 0

# %%
def getMergeConflictsGit2(project_name,release):
    connection = connectDBPandas()
    query = """select count(repo_name) conflicts from MERGE_CONFLICT_GIT 
    where repo_name ilike %s AND release_id like %s;"""

    df = pd.read_sql_query(query,con=connection,params=[project_name,release])
    connection.dispose()
    return df

# %%
def getBugs(project_name,release):
    query = """select count(id) bugs from ISSUE 
    where repo_name like %s AND release_id like %s AND ISBUG IS TRUE;"""

    connection = connectDBPandas()
    df = pd.read_sql_query(query,con=connection,params=[project_name,release])
    connection.dispose()
    return df

# %%
def getIssues(project_name,release):
    query = """select count(id) issues from ISSUE 
    where repo_name like %s AND release_id like %s;"""

    connection = connectDBPandas()
    df = pd.read_sql_query(query,con=connection,params=[project_name,release])
    connection.dispose()
    return df

# %%
#https://www.kite.com/python/answers/how-to-remove-outliers-from-a-pandas-dataframe-in-python
def removeOutliers(df):
    z_scores = stats.zscore(df)
    abs_z_scores = np.abs(z_scores)
    filtered_entries = (abs_z_scores < 3).all(axis=1)
    df_filtered = df[filtered_entries]

    return df_filtered

# %%
def checkValues(df):
    if (df == 0).all():
        return True
    else:
        i=v=0
        v = df[0]
        for a in df:
            if a != v:
                return True
            
        return False

# %%
def insertMetricsRelease(repo_name,release,release_creation,ci,qtdPR,commit_size_mean,commit_size_median,commit_size_perfile_mean,commit_size_perfile_median,test_volume_mean,test_volume_median,communication_mean,communication_median,author_frequency_mean,author_frequency_median,merge_conflicts,merge_conflictsGit,bugs,qtybuilds,commits,test_vol_proportional,age,bugs_ratio):
    try:
        query = """INSERT INTO METRICS_RELEASES(repo_name,release_id,created_at,ci,commit_size_mean,commit_size_median,
                    commit_size_perfile_mean,commit_size_perfile_median,test_volume_mean,test_volume_median,
                    communication_mean,communication_median,author_frequency_mean,author_frequency_median,merge_conflicts,merge_conflicts_git,bugs,qtd_pull_request,qty_builds,qty_commits,
                    test_volume_proportional,age,bugs_ratio)
                VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);"""

        query_print=f"""INSERT INTO METRICS_RELEASES(repo_name,release_id,created_at,ci,commit_size_mean,commit_size_median,
                    commit_size_perfile_mean,commit_size_perfile_median,test_volume_mean,test_volume_median,
                    communication_mean,communication_median,author_frequency_mean,author_frequency_median,merge_conflicts,merge_conflicts_git,bugs,qtd_pull_request,qty_builds,qty_commits,
                    test_volume_proportional,age,bugs_ratio)
                VALUES({repo_name},{release},{release_creation},{ci},{commit_size_mean},{commit_size_median},{commit_size_perfile_mean},{commit_size_perfile_median},{test_volume_mean},{test_volume_median},{communication_mean},{communication_median},{author_frequency_mean},{author_frequency_median},{merge_conflicts},{merge_conflictsGit},{bugs},{qtdPR},{qtybuilds},{commits},{test_vol_proportional},{age},{bugs_ratio});"""
        
        #print(query_print)
        
        connection = connectDB()
        cursor = connection.cursor()
        
        cursor.execute(query, [repo_name,release,release_creation,ci,commit_size_mean,commit_size_median,commit_size_perfile_mean,commit_size_perfile_median,test_volume_mean,test_volume_median,communication_mean,communication_median,author_frequency_mean,author_frequency_median,merge_conflicts,merge_conflictsGit,bugs,qtdPR,qtybuilds,commits,test_vol_proportional,age,bugs_ratio])
        connection.commit()
        connection.close()
    except psycopg2.IntegrityError as e:
        print ("==============================================================")
        print ("Error while updating into PostgreSQL. insertMetricsRelease >>> Exception: {}".format(e)) 
        print('Project: {}    Release - {}'.format(repo_name,release))
        connection.close()
    except Exception as e:
        print ("==============================================================")
        print ("Error while processing insertMetricsRelease >>> Exception: {}".format(e)) 
        print('Project: {}    Release - {}'.format(repo_name,release))

# %%
def getBuilds(repo_name,release):
    #print('****** Computing Build Health. Repo {}'.format(repo_name))
    
    query = """SELECT state FROM builds_mined WHERE 
            repo_name like %s AND release_id like %s;"""

    connection = connectDB()
    cursor = connection.cursor()
    
    cursor.execute(query, [repo_name,release])
    rows = cursor.fetchall()
    connection.close()
    return rows
