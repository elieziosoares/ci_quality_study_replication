# %% [markdown]
# ### Prepare the data
# - Flagging the PRs under analysis and fixing analysis dates (updatePRsProject())

# %%
projects = getProjects()

for repo in projects:
    repo_name = repo[0]
    repo_url = repo[1]
    init_date = repo[2]
    interval = repo[3]
    
    print('\n\n----------- {} - INITIALIZING {} -----------\n\n'.format(datetime.now().strftime("%H:%M:%S"),repo_name))
    
    updatePRsProject(repo_name,init_date,interval)
# Out:
# ----------- 12:43:35 - INITIALIZING z-song/laravel-admin -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-872f8a00b9da> in <module>
#       9     print('\n\n----------- {} - INITIALIZING {} -----------\n\n'.format(datetime.now().strftime("%H:%M:%S"),repo_name))
#      10
# ---> 11     updatePRsProject(repo_name,init_date,interval)
#
# <ipython-input-39-19c7ae207edc> in updatePRsProject(project, init_date, interval)
#       1 def updatePRsProject(project,init_date,interval):
# ----> 2     init_date = selectFirstPRMonth(project,init_date.month,init_date.year)
#       3
#       4     #get the date ending the period range
#       5     end_date = init_date + relativedelta(months=interval-1)
#
# <ipython-input-33-67624250f532> in selectFirstPRMonth(project, month, year)
#      10             order by closed_at limit 1;"""
#      11
# ---> 12     cursor.execute(query, [month,year,project])
#      13     row = cursor.fetchone()
#      14
#
# /home/elieziosoares/anaconda3/lib/python3.8/encodings/utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:

# %% [markdown]
# ## Mining Commit Metadata and Communication

# %%
projects = getProjects()

for repo in projects:
    repo_name = repo[0]
    repo_url = repo[1]
    init_date = repo[2]
    interval = repo[3]
    
    mined = True
    
    print('\n\n----------- {} - INITIALIZING {} -----------\n\n'.format(datetime.now().strftime("%H:%M:%S"),repo_name))
    
    updatePRsProject(repo_name,init_date,interval)
    #pr_number,COMMENTS_URL, commits_url, review_comments_url
    
    #collect pull requests for each repo
    PRs = getPRs(repo_name)
    for PR in PRs:    
        #collect number of comments and save it on pullrequests table
        communication_mined = setCommunication(repo_name, PR[0], PR[1],PR[3])      
            
        #collect the commits for each pull request
        commits_mined = getCommits(PR[2],repo_name, PR[0])
        

        #Check 'mined' flag on table pullrequests.
        if communication_mined and commits_mined:
            checkPRMined(repo_name, PR[0])
        else:
            mined = False
            
        if PR[4] is not None:
            recordMergeCommit(PR[4])
    
   
    #Check 'mined' flag on table projects.
    checkProjectMined(repo_name, mined)
    
    print('\n\n----------- {}'.format(datetime.now().strftime("%H:%M:%S")))
# Out:
# ----------- 12:46:18 - INITIALIZING z-song/laravel-admin -----------
#
#
# z-song/laravel-admin - 2018-03-02 13:50:20-03:00 - 42 - 2021-08-31 11:49:24-03:00
# + Project: z-song/laravel-admin    PR - 4935
# ....Updating pullrequest: UPDATE  PULLREQUESTS set "Comments" = 0, review_comments = 0 WHERE project_name like z-song/laravel-admin and id = 4935;
# Commit 1/1 - https://api.github.com/repos/z-song/laravel-admin/pulls/4935/commits
# ....Updating pullrequest: UPDATE  PULLREQUESTS set commits = 1 WHERE project_name like z-song/laravel-admin and id = 4935;
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(20cd1cdbedce0514d7d78cfe5e35f474e48b0f6a) already exists.
#
# Commit: 20cd1cdbedce0514d7d78cfe5e35f474e48b0f6a
# + Project: z-song/laravel-admin    PR - 5342
# ....Updating pullrequest: UPDATE  PULLREQUESTS set "Comments" = 0, review_comments = 0 WHERE project_name like z-song/laravel-admin and id = 5342;
# Commit 1/2 - https://api.github.com/repos/z-song/laravel-admin/pulls/5342/commits
# Commit 2/2 - https://api.github.com/repos/z-song/laravel-admin/pulls/5342/commits
# ....Updating pullrequest: UPDATE  PULLREQUESTS set commits = 2 WHERE project_name like z-song/laravel-admin and id = 5342;
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(a44e8e6e213e3b072bc5add4f8bb9192572f7217) already exists.
#
# Commit: a44e8e6e213e3b072bc5add4f8bb9192572f7217
#
#
# ----------- 12:46:27

# %% [markdown]
# ### Recording merge commits in another table

# %%
projects = getProjectsMergeCommits()

for repo in projects:
    repo_name = repo[0]
    repo_url = repo[1]
    init_date = repo[2]
    interval = repo[3]
    

    print('\n\n----------- {} - INITIALIZING {} -----------\n\n'.format(datetime.now().strftime("%H:%M:%S"),repo_name))
    
    #collect pull requests for each repo
    PRs = getPRsMerge(repo_name)
    for PR in PRs:  
        recordMergeCommit(PR[0])
# Out:
# ----------- 23:20:12 - INITIALIZING 3b1b/manim -----------
#
#
#
#
# ----------- 23:20:35 - INITIALIZING 3lvis/Sync -----------
#
#
#
#
# ----------- 23:20:47 - INITIALIZING 42wim/matterbridge -----------
#
#
#
#
# ----------- 23:21:09 - INITIALIZING 47degrees/nine-cards-v2 -----------
#
#
#
#
# ----------- 23:21:34 - INITIALIZING 9fans/plan9port -----------
#
#
#
#
# ----------- 23:21:45 - INITIALIZING acacha/adminlte-laravel -----------
#
#
#
#
# ----------- 23:21:49 - INITIALIZING actorapp/actor-platform -----------
#
#
#
#
# ----------- 23:21:59 - INITIALIZING adambard/learnxinyminutes-docs -----------
#
#
#
#
# ----------- 23:24:18 - INITIALIZING AdAway/AdAway -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(3fafaab7b81864141788b02680291e16dbe245b1) already exists.
#
# Commit: 3fafaab7b81864141788b02680291e16dbe245b1
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(3fafaab7b81864141788b02680291e16dbe245b1) already exists.
#
# Commit: 3fafaab7b81864141788b02680291e16dbe245b1
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(3fafaab7b81864141788b02680291e16dbe245b1) already exists.
#
# Commit: 3fafaab7b81864141788b02680291e16dbe245b1
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(919ced105a5a5db008b568b12fda0207be55dbe4) already exists.
#
# Commit: 919ced105a5a5db008b568b12fda0207be55dbe4
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(21345b247dd8ed98d0a134a536dfb9a84d4d5284) already exists.
#
# Commit: 21345b247dd8ed98d0a134a536dfb9a84d4d5284
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4f052733c92743d69dac7f020bf97d00e71a530) already exists.
#
# Commit: f4f052733c92743d69dac7f020bf97d00e71a530
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b) already exists.
#
# Commit: cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b) already exists.
#
# Commit: cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b) already exists.
#
# Commit: cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b) already exists.
#
# Commit: cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b) already exists.
#
# Commit: cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b) already exists.
#
# Commit: cdf50ab43f20f1bf2ed23c7034f5a89129b4a67b
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(99df58498a2602f5b84d1578a3878cd5ca6f5d4d) already exists.
#
# Commit: 99df58498a2602f5b84d1578a3878cd5ca6f5d4d
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(8acafc72f753084fb668315cf23e745c09b30a01) already exists.
#
# Commit: 8acafc72f753084fb668315cf23e745c09b30a01
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b95a94c14b82b214a03363d6c31e5512c7ac6825) already exists.
#
# Commit: b95a94c14b82b214a03363d6c31e5512c7ac6825
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(4f1a0cd5965b55cf196f22d7492cfd83fc74c051) already exists.
#
# Commit: 4f1a0cd5965b55cf196f22d7492cfd83fc74c051
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(4f1a0cd5965b55cf196f22d7492cfd83fc74c051) already exists.
#
# Commit: 4f1a0cd5965b55cf196f22d7492cfd83fc74c051
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(4f1a0cd5965b55cf196f22d7492cfd83fc74c051) already exists.
#
# Commit: 4f1a0cd5965b55cf196f22d7492cfd83fc74c051
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(4f1a0cd5965b55cf196f22d7492cfd83fc74c051) already exists.
#
# Commit: 4f1a0cd5965b55cf196f22d7492cfd83fc74c051
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(4f1a0cd5965b55cf196f22d7492cfd83fc74c051) already exists.
#
# Commit: 4f1a0cd5965b55cf196f22d7492cfd83fc74c051
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(efb1718f012f26f06133807dcb5980e7af147c28) already exists.
#
# Commit: efb1718f012f26f06133807dcb5980e7af147c28
# ==============================================================
# ...
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
#
#
# ----------- 03:43:16 - INITIALIZING twitter/cassovary -----------
#
#
#
#
# ----------- 03:43:21 - INITIALIZING twitter/scalding -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
#
#
# ----------- 03:44:14 - INITIALIZING typekit/webfontloader -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
#
#
# ----------- 03:44:21 - INITIALIZING TYPO3/TYPO3.CMS -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
#
#
# ----------- 03:44:33 - INITIALIZING tzutalin/labelImg -----------
#
#
#
#
# ----------- 03:44:40 - INITIALIZING uber/aresdb -----------
#
#
#
#
# ----------- 03:45:02 - INITIALIZING uber/react-vis -----------
#
#
#
#
# ----------- 03:45:29 - INITIALIZING UnionOfRAD/lithium -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
#
#
# ----------- 03:45:59 - INITIALIZING Unitech/pm2 -----------
# ----------- 03:46:26 - INITIALIZING viatsko/awesome-vscode -----------
#
#
#
#
# ----------- 03:46:37 - INITIALIZING vmware-tanzu/sonobuoy -----------
#
#
#
#
# ----------- 03:47:06 - INITIALIZING vscode-icons/vscode-icons -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(dc7872262c9b059c574bd16fc4cfedbb6bdf156e) already exists.
#
# Commit: dc7872262c9b059c574bd16fc4cfedbb6bdf156e
#
#
# ----------- 03:48:09 - INITIALIZING vsouza/awesome-ios -----------
#
#
#
#
# ----------- 03:49:52 - INITIALIZING vulcand/vulcand -----------
#
#
#
#
# ----------- 03:49:59 - INITIALIZING VulcanJS/Vulcan -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
#
#
# ----------- 03:50:45 - INITIALIZING vurtun/nuklear -----------
#
#
#
#
# ----------- 03:50:55 - INITIALIZING watson-developer-cloud/swift-sdk -----------
#
#
#
#
# ----------- 03:51:14 - INITIALIZING weaveworks/weave -----------
#
#
#
#
# ----------- 03:52:15 - INITIALIZING wenzhixin/bootstrap-table -----------
#
#
#
#
# ----------- 03:53:05 - INITIALIZING weppos/whois -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
#
#
# ----------- 03:53:15 - INITIALIZING WorldBrain/Memex -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(b7e22d62f9d575ad120414ae6ee3c772b323a050) already exists.
#
# Commit: b7e22d62f9d575ad120414ae6ee3c772b323a050
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(2a2c5090b0b623d2827121b6e471254842e84d71) already exists.
#
# Commit: 2a2c5090b0b623d2827121b6e471254842e84d71
#
#
# ----------- 03:53:40 - INITIALIZING WPO-Foundation/webpagetest -----------
#
#
#
#
# ----------- 03:53:59 - INITIALIZING writefreely/writefreely -----------
#
#
#
#
# ----------- 03:54:10 - INITIALIZING xmartlabs/Eureka -----------
#
#
#
#
# ----------- 03:54:36 - INITIALIZING xmartlabs/XLForm -----------
#
#
#
#
# ----------- 03:54:51 - INITIALIZING XVimProject/XVim -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=() already exists.
#
# Commit:
#
#
# ----------- 03:55:04 - INITIALIZING yabwe/medium-editor -----------
#
#
#
#
# ----------- 03:55:27 - INITIALIZING yarnpkg/yarn -----------
#
#
#
#
# ----------- 03:56:50 - INITIALIZING YMFE/yapi -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(e2a1b2d1c8f52b9ad03e432ffc3f726621796646) already exists.
#
# Commit: e2a1b2d1c8f52b9ad03e432ffc3f726621796646
#
#
# ----------- 03:56:58 - INITIALIZING zalmoxisus/redux-devtools-extension -----------
#
#
#
#
# ----------- 03:57:05 - INITIALIZING zendesk/maxwell -----------
#
#
#
#
# ----------- 03:57:39 - INITIALIZING z-song/laravel-admin -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(a7448903900eda8e175e9f2d55105f14142b38b8) already exists.
#
# Commit: a7448903900eda8e175e9f2d55105f14142b38b8
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(765cb039484e5d81dbbbf1e358ac236607854be6) already exists.
#
# Commit: 765cb039484e5d81dbbbf1e358ac236607854be6
#
#
# ----------- 03:58:32 - INITIALIZING zyedidia/micro -----------
#
#
#
#
# ----------- 03:59:05 - INITIALIZING zzzeek/sqlalchemy -----------
#
#
# ==============================================================
# Error while recordMergeCommit >>> Exception: duplicate key value violates unique constraint "merge_commits_pkey"
# DETAIL:  Key (commit_sha)=(f4739f51899d434a968e666367ccc0c08cb9f1f1) already exists.
#
# Commit: f4739f51899d434a968e666367ccc0c08cb9f1f1

# %% [markdown]
# ## Aux Functions

# %%
def getCommits(commits_url,repo_name,pr_number):    
    try:
        commits = requestAPI(commits_url)
        if commits is not None:
            qty_commits = len(commits)
            i=0
            for commit in commits:
                i+=1
                if commit['author'] is not None and len(commit['author']) > 0:
                    storeAuthor(commit['author'])
                saveCommit(commit,repo_name,pr_number)
                print('Commit {}/{} - {}'.format(i,qty_commits,commits_url))
        else:
            qty_commits = 0
            
    except psycopg2.IntegrityError as e:
        print ("==============================================================")
        print ("Error while inserting into PostgreSQL. getCommits >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {} '.format(repo_name, pr_number))
        return False
    except Exception as e:
        print ("==============================================================")
        print ("Error while processing getCommits >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))
        return False
    
    try:
        query = """UPDATE  PULLREQUESTS 
            set commits = %s
            WHERE project_name like %s and pr_number = %s;"""
        
        print('....Updating pullrequest: UPDATE  PULLREQUESTS set commits = {} WHERE project_name like {} and id = {};'.format(qty_commits,repo_name,pr_number))

        connection = connectDB()
        cursor = connection.cursor()
        cursor.execute(query, [qty_commits,repo_name,pr_number])
        connection.commit()
        connection.close()
    except psycopg2.IntegrityError as e:
        print ("\n==============================================================")
        print ("Error while inserting into PostgreSQL. getCommits - PullRequests >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {} '.format(repo_name, pr_number))
        connection.close()
        connection = connectDB()
        return False
    except Exception as e:
        print ("\n==============================================================")
        print ("Error while processing getCommits - PullRequests >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))
        return False
    
    return True

# %%
def saveCommit(commit,repo_name,pr_number):
    connection = connectDB()
    cursor = connection.cursor()
    query = """SELECT * FROM commits WHERE commit_sha like %s;"""
    cursor.execute(query,[commit['sha']])
    row = cursor.fetchone()
    connection.commit()
 
    if row is None:  
        cursor_insert = connection.cursor()           
        query = """INSERT INTO commits (commit_sha,commit_date,msg,author_id) 
        VALUES(%s,%s,%s,%s);"""
    
        
        if commit['author'] is not None and len(commit['author']) > 0:
            commit_id = commit['author']['id']
        else:
            commit_id = None
            
        cursor_insert = connection.cursor()
        cursor_insert.execute(query, [commit['sha'],commit['commit']['committer']['date'],commit['commit']['message'],commit_id])
        connection.commit()
    
    cursor_insert = connection.cursor()           
    query = """INSERT INTO commit_PR (pr_number,project_name,commit_sha) 
    VALUES(%s,%s,%s);"""

    cursor_insert = connection.cursor()
    cursor_insert.execute(query, [str(pr_number), repo_name, commit['sha']])
    connection.commit()
    connection.close()

# %%
import psycopg2
import os
import requests 
import time
import pytz    
import calendar
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import pandas as pd
from scipy import stats
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
from bs4 import BeautifulSoup

# %%
def connectDB():
    f = open('/home/elieziosoares/psql_pwd.txt', "r")
    pwd = f.readline().replace('\n','')
    
    return psycopg2.connect(user = "postgres",
                              password = pwd,
                              host = "127.0.0.1",
                              port = "5432",
                              database = "Causal_CI_Quality_v3")

# %% [markdown]
# #### Step 1 - Select projects not mined yet.

# %%
def getProjects():
    #query = """select repo_name,repo_url,analysis_init, qtd_pull_requests_months from projects 
    #where issues_selected is true and prs_selected is true and 
    #(commits_mined is not true or comments_mined is not true or analysis_finish is null)
    #order by repo_name;"""
    query = """select repo_name,repo_url,analysis_init, qtd_pull_requests_months from projects 
    where issues_selected is true and prs_selected is true
    order by repo_name;"""

    connection = connectDB()
    cursor = connection.cursor()
    cursor.execute(query)
    result = cursor.fetchall()
    connection.close()
    return result

# %%
def getProjectsMergeCommits():
    query = """SELECT * FROM PROJECTS WHERE commits_mined2 is True order by repo_name;"""

    connection = connectDB()
    cursor = connection.cursor()
    cursor.execute(query)
    result = cursor.fetchall()
    connection.close()
    return result

# %%
def getPRsMerge(project_name):
    query = """select merge_commit_sha,id_user from pullrequests where merge_commit_sha is not null
    and project_name like %s"""
    
    connection = connectDB()
    cursor = connection.cursor()
    cursor.execute(query, [project_name])
    result = cursor.fetchall()
    connection.close()
    return result

# %%
def recordMergeCommit(commit_sha):
    try:
        query = """insert into merge_commits (commit_sha) 
            values(%s)"""
        
        connection = connectDB()
        cursor = connection.cursor()
        cursor.execute(query, [commit_sha])
        connection.commit()
        connection.close()
    except Exception as e:
        print ("==============================================================")
        print ("Error while recordMergeCommit >>> Exception: {}".format(e)) 
        print('Commit: {}'.format(commit_sha))

# %%
def updatePRsProject(project,init_date,interval):
    init_date = selectFirstPRMonth(project,init_date.month,init_date.year)
    
    #get the date ending the period range
    end_date = init_date + relativedelta(months=interval-1)
    #get the last day of such month
    end_day = calendar.monthrange(end_date.year, end_date.month)
    #Construct a date time representing the end of this month
    end_date = datetime(end_date.year, end_date.month, end_day[1], 23,59,59,999999)
    #get the PR closest to this date (PR.date <= end_date)
    end_date = selectLastPRMonth(project,end_date)

    print('{} - {} - {} - {}'.format(project,init_date,interval,end_date))
    updatePRsInPeriod(project,init_date,end_date)
    updateProjectDates(project,init_date,end_date)

# %%
def updateProjectDates(repo_name,init_date,finish_date):
    try:
        query = """UPDATE  PROJECTS 
            set analysis_init = %s,
            analysis_finish = %s
            WHERE repo_name like %s"""
        
        connection = connectDB()
        cursor = connection.cursor()
        cursor.execute(query, [init_date,finish_date,repo_name])
        connection.commit()
        connection.close()
    except Exception as e:
        print ("==============================================================")
        print ("Error while updateProjectDates >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))

# %%
def checkProjectMined(repo_name, mined):
    try:
        query = """UPDATE  PROJECTS 
            set commits_mined = %s,
            comments_mined = %s
            WHERE repo_name like %s"""
        
        connection = connectDB()
        cursor = connection.cursor()
        cursor.execute(query, [mined,mined,repo_name])
        connection.commit()
        connection.close()
    except Exception as e:
        print ("==============================================================")
        print ("Error while checkProjectMined >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))

# %%
def updatePRsInPeriod(repo_name,init_date,finish_date):
    try:
        query = """UPDATE  PULLREQUESTS 
            set InPeriodRQ1 = True
            WHERE project_name like %s and closed_at >= %s and closed_at <= %s;"""
        
        connection = connectDB()
        cursor = connection.cursor()
        cursor.execute(query, [repo_name,init_date,finish_date])
        connection.commit()
        connection.close()
    except Exception as e:
        print ("==============================================================")
        print ("Error while updatePRsInPeriod >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))

# %%
def selectFirstPRMonth(project,month, year):
#def selectFirstPRMonth(project,month,year):
    connection = connectDB()
    cursor = connection.cursor()
        
    query = """SELECT closed_at from pullrequests where  
            date_part('month', closed_at) = %s
            AND date_part('year', closed_at) = %s 
            AND project_name like %s
            order by closed_at limit 1;"""

    cursor.execute(query, [month,year,project])
    row = cursor.fetchone()
    
    cursor.close()
    connection.close()
    if row is not None:
        return row[0]
    else:
        return None

# %%
#def selectLastPRMonth(project,month,year):
def selectLastPRMonth(project,date):
   
    #query = """SELECT closed_at from pullrequests where  
    #    date_part('month', closed_at) = %s
    #    AND date_part('year', closed_at) = %s 
    #    AND project_name like %s
    #    order by closed_at desc limit 1;"""
    
    query = """SELECT closed_at from pullrequests where  
        closed_at <= %s
        AND project_name like %s
        order by closed_at desc limit 1;"""

    connection = connectDB()
    cursor = connection.cursor()
    #cursor.execute(query, [month,year,project])
    cursor.execute(query, [date,project])
    row = cursor.fetchone()
    cursor.close()
    connection.close()
    if row is not None:
        return row[0]
    else:
        return None

# %%
def getPRs(project_name):
    query = """select pr_number,COMMENTS_URL, commits_url, review_comments_url,merge_commit_sha from PULLREQUESTS 
    where project_name like %s and mined1 is not True and inperiodrq1 is true;"""
    
    connection = connectDB()
    cursor = connection.cursor()
    cursor.execute(query, [project_name])
    result = cursor.fetchall()
    connection.close()
    return result

# %%
def checkPRMined(project_name,pr_number):
    try:
        query = """UPDATE  PULLREQUESTS 
            set mined1 = True
            WHERE project_name like %s and pr_number = %s;"""

        connection = connectDB()
        cursor = connection.cursor()
        cursor.execute(query, [repo_name,pr_number])
        connection.commit()
        connection.close()
    except Exception as e:
        print ("==============================================================")
        print ("Error while checkPRMined >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))

# %%
def storeAuthor(author):
    connection = connectDB()
    cursor = connection.cursor()

    query = """SELECT * FROM gh_User WHERE id = """+str(author['id'])
    cursor.execute(query)
    row = cursor.fetchone()
    connection.commit()
    if row is not None:  
        return
        
    cursor_insert = connection.cursor()
    query = """INSERT INTO gh_User (id,events_url, followers_url, login, organizations_url, repos_url,starred_url, subscriptions_url,user_type) 
    VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
        
    cursor_insert = connection.cursor()
    cursor_insert.execute(query, [author['id'],author['events_url'],author['followers_url'],author['login'],author['organizations_url'],author['repos_url'],author['starred_url'],author['subscriptions_url'],author['type']])
    connection.commit()
    connection.close()

# %%
def storeMessage(message,repo_name, pr_number):      
    try:
        query = """INSERT INTO messages (pr_number,project_name,url,html_url,id_message,node_id,body,user_id, created_at) 
        VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s)"""

        if message['user'] is not None and len(message['user']) > 0:
            commit_id = message['user']['id']
        else:
            commit_id = None

        connection = connectDB()
        cursor_insert = connection.cursor()
        cursor_insert.execute(query, [str(pr_number), repo_name, message['url'],message['html_url'],message['id'],message['node_id'],message['body'],commit_id,str(message['created_at'])])
        connection.commit()
        connection.close()
    except Exception as e:
        print ("==============================================================")
        print ("Error while storeMessage >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  Message: {} '.format(repo_name, pr_number,message['id']))

# %%
def setCommunication(repo_name, pr_number, comments_url, review_comments_url):
    try:
        print('+ Project: {}    PR - {}'.format(repo_name, pr_number))
        
        messages = requestAPI(comments_url)
        if messages is not None:
            qtycomments = len(messages)
            print('....Comments: {}'.format(qtycomments))
            
            for m in messages:
                if m['user'] is not None and len(m['user']) > 0:
                    storeAuthor(m['user'])
                storeMessage(m,repo_name, pr_number)
        else:
            qtycomments = 0
    except psycopg2.IntegrityError as e:
        print ("==============================================================")
        print ("Error while inserting into PostgreSQL. setCommunication >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {} '.format(repo_name, pr_number))
        #return False
    except Exception as e:
        print ("==============================================================")
        print ("Error while processing setCommunication >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))
        return False
            
    try:
        rev_messages = requestAPI(review_comments_url)
        if rev_messages is not None:
            qtyrevcomments = len(rev_messages)
            print('....Review Comments: {}'.format(qtyrevcomments))

            for m in rev_messages:
                if m['user'] is not None and len(m['user']) > 0:
                    storeAuthor(m['user'])
                storeMessage(m,repo_name, pr_number)
        else:
            qtyrevcomments = 0
    except psycopg2.IntegrityError as e:
        print ("==============================================================")
        print ("Error while inserting into PostgreSQL. setCommunication >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {} '.format(repo_name, pr_number))
        #return False
    except Exception as e:
        print ("==============================================================")
        print ("Error while processing setCommunication >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))
        return False
    
    try:
        query = """UPDATE  PULLREQUESTS 
            set "Comments" = %s,
            review_comments = %s
            WHERE project_name like %s and pr_number = %s;"""
        
        print('....Updating pullrequest: UPDATE  PULLREQUESTS set "Comments" = {}, review_comments = {} WHERE project_name like {} and id = {};'.format(qtycomments, qtyrevcomments,repo_name,pr_number))

        connection = connectDB()
        cursor = connection.cursor()
        cursor.execute(query, [qtycomments, qtyrevcomments,repo_name,pr_number])
        connection.commit()
        connection.close()
    except psycopg2.IntegrityError as e:
        print ("==============================================================")
        print ("Error while inserting into PostgreSQL. setCommunication >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {} '.format(repo_name, pr_number))
        connection.close()
        connection = connectDB()
        return False
    except Exception as e:
        print ("==============================================================")
        print ("Error while processing setCommunication >>> Exception: {}".format(e)) 
        print('Project: {}    PR - {}  '.format(repo_name, pr_number))
        return False
    
    return True

# %%
tokens =['token 80665cc2fa2fcf9f6368ac32014eda5bf5083bd3', 'token 1f3a6e7d066f937c163900db140e4506a2f3dd87', 'token 1f5163feb5b40cf70542f3a4360b957d9d6a668a']
i_token =0



def requestAPI(URL):
    # api-endpoint 
    global i_token
    
    if (len(tokens)-1) > i_token:
        i_token += 1
    else:
        i_token = 0
        
    r = requests.get(url = URL, headers={'Authorization': tokens[i_token]}).json()
    #r = requests.get(url = URL).json()
    
    if len(r) > 0:
        try:
            #print('keys: {}'.format(r.keys()))
            
            if isinstance(r, dict) and 'message' in r.keys():
                print('{} -- {}'.format(datetime.now().strftime("%H:%M:%S"),r['message']))
                if 'API rate limit exceeded' in r['message']:
                    time.sleep(600)
                    requestAPI(URL)

            return r
        except Exception as e:
            print('\n Erro no request get: {}'.format(e))
            print(r)
    else:
        return None
