# %% [markdown]
# ## Release and Tag mining
#
# - Get and store all tags and releases from selected repositories for rq1.

# %%
repos = getProjects()
i=0
for repo in repos:
    project = repo[0]
    i += 1
    print('\n\n\n{}/{} Project - {}\n\n\n'.format(i,len(repos),project))
    
    mineTags(project)
    mineReleases(project)
# Out:
# 1/7 Project - AutoSpotting/AutoSpotting
#
#
#
#
#
#
# 2/7 Project - docker-archive/deploykit
#
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjEuMA==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjEuMA==) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/git/commits/51f5aa5d2a8cf807ffcac8758d5e1be7916fd36e
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjIuMA==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjIuMA==) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/git/commits/f432fa458497662c5dbf2c48556dd5ca13c43df8
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjMuMA==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjMuMA==) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/git/commits/645e798e720d496b13202f1b8c52f2f19777285e
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjMuMQ==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjMuMQ==) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/git/commits/b919e4f38abaa4d0f1c97f1fb267a62abf1e90c0
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjQuMA==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjQuMA==) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/git/commits/7841ecdf062c9d563938d99bd8a8352d472d8994
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjQuMQ==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjQuMQ==) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/git/commits/291de15ec062445b1064ef052292f4eb7005e5f9
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjU=) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNTU4MTE0NzU6cmVmcy90YWdzL3YwLjU=) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/git/commits/3d2670e484176ce474d4b3d171994ceea7054c02
#
#
#
#
# ==============================================================
# Error while processing storeRelease >>> Exception: duplicate key value violates unique constraint "releases_pkey"
# DETAIL:  Key (node_id)=(MDc6UmVsZWFzZTY1MDczODg=) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/releases/6507388
#
#
#
#
# ==============================================================
# Error while processing storeRelease >>> Exception: duplicate key value violates unique constraint "releases_pkey"
# DETAIL:  Key (node_id)=(MDc6UmVsZWFzZTU1NzQwNjc=) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/releases/5574067
#
#
#
#
# ==============================================================
# Error while processing storeRelease >>> Exception: duplicate key value violates unique constraint "releases_pkey"
# DETAIL:  Key (node_id)=(MDc6UmVsZWFzZTU1MDU5NTE=) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/releases/5505951
#
#
#
#
# ==============================================================
# Error while processing storeRelease >>> Exception: duplicate key value violates unique constraint "releases_pkey"
# DETAIL:  Key (node_id)=(MDc6UmVsZWFzZTUzOTk0Njc=) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/releases/5399467
#
#
#
#
# ==============================================================
# Error while processing storeRelease >>> Exception: duplicate key value violates unique constraint "releases_pkey"
# DETAIL:  Key (node_id)=(MDc6UmVsZWFzZTUzMzQzMDk=) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/releases/5334309
#
#
#
#
# ==============================================================
# Error while processing storeRelease >>> Exception: duplicate key value violates unique constraint "releases_pkey"
# DETAIL:  Key (node_id)=(MDc6UmVsZWFzZTUxODYxNTM=) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/releases/5186153
#
#
#
#
# ==============================================================
# Error while processing storeRelease >>> Exception: duplicate key value violates unique constraint "releases_pkey"
# DETAIL:  Key (node_id)=(MDc6UmVsZWFzZTQ4NDgyMzQ=) already exists.
#
# Project: docker-archive/deploykit    Commit - https://api.github.com/repos/docker-archive/deploykit/releases/4848234
#
#
#
#
#
# 3/7 Project - gitscrum-ce/laravel-gitscrum
#
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMS4w) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMS4w) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/tags/108a330b657c8ea1e1d468a4f9c79b58b4256ee4
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMy4w) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMy4w) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/commits/e1504ad52337a733350c8ed2bb74aa908b6c65d4
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuNy4w) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuNy4w) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/commits/f5cd2bc0dc9e31896b43736bf7e438403a2c6412
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuOS4w) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuOS4w) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/commits/8ed46585f91c279209563f0752103692ab8a8b6d
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMTEuMA==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMTEuMA==) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/commits/9485f280fd99d1888da732dc2ecab348fcabfe53
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMTMuMA==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMTMuMA==) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/commits/6b1563818e7d1022d5cba2608d9a2187718e13db
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMTUuMA==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMTUuMA==) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/commits/e3eb3ca6b903ac6595a3787b595762c21ad641c3
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMTcuMA==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzAuMTcuMA==) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/commits/fefa9523e9fea1c7888e1ce7f0653c188efb63d8
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzEuMS4w) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmNzQxNTIzMjM6cmVmcy90YWdzLzEuMS4w) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/git/commits/fa23520813633a2f46b32269896f3b1f35a9b8f6
#
#
#
#
# ==============================================================
# Error while processing storeRelease >>> Exception: duplicate key value violates unique constraint "releases_pkey"
# DETAIL:  Key (node_id)=(MDc6UmVsZWFzZTc5NTU5Mzg=) already exists.
#
# Project: gitscrum-ce/laravel-gitscrum    Commit - https://api.github.com/repos/gitscrum-ce/laravel-gitscrum/releases/7955938
#
#
#
#
#
# 4/7 Project - mdbootstrap/mdb-ui-kit
#
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmMjMwNjkzOTk6cmVmcy90YWdzLzEuMC4wLWFscGhhMQ==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmMjMwNjkzOTk6cmVmcy90YWdzLzEuMC4wLWFscGhhMQ==) already exists.
#
# Project: mdbootstrap/mdb-ui-kit    Commit - https://api.github.com/repos/mdbootstrap/mdb-ui-kit/git/commits/8ca578ca17f2b072ceb48ccc049d2af9f8e47886
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmMjMwNjkzOTk6cmVmcy90YWdzLzEuMC4wLWFscGhhMg==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmMjMwNjkzOTk6cmVmcy90YWdzLzEuMC4wLWFscGhhMg==) already exists.
#
# Project: mdbootstrap/mdb-ui-kit    Commit - https://api.github.com/repos/mdbootstrap/mdb-ui-kit/git/commits/fa8ceb904e67bf424d5d224ace99c3a12a15b6bf
#
#
#
#
# ==============================================================
# Error while processing storeTag >>> Exception: duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmMjMwNjkzOTk6cmVmcy90YWdzLzEuMC4wLWFscGhhMw==) already exists.
#
# duplicate key value violates unique constraint "tag_pkey"
# DETAIL:  Key (node_id)=(MDM6UmVmMjMwNjkzOTk6cmVmcy90YWdzLzEuMC4wLWFscGhhMw==) already exists.
#
# Project: mdbootstrap/mdb-ui-kit    Commit - https://api.github.com/repos/mdbootstrap/mdb-ui-kit/git/commits
# 		 2021-10-19T10:01:36Z - refs/tags/6.21.7
# 		 2021-10-26T11:20:07Z - refs/tags/6.22.0
# 		 2021-12-02T22:40:14Z - refs/tags/6.22.1
# 		 2021-12-05T22:34:04Z - refs/tags/6.22.2
# 		 2021-12-19T22:33:31Z - refs/tags/6.22.3
# 		 2021-12-19T22:33:31Z - 6.22.3
# 		 2021-12-05T22:34:04Z - 6.22.2
# 		 2021-12-02T22:40:14Z - 6.22.1
# 		 2021-10-26T11:20:07Z - 6.22.0
# 		 2021-10-19T10:01:36Z - 6.21.7
# 		 2021-10-10T15:23:49Z - 6.21.6
# 		 2021-10-10T13:04:04Z - 6.21.5
# 		 2021-10-09T17:05:42Z - 6.21.4
# 		 2021-10-03T17:47:02Z - 6.21.3
# 		 2021-09-09T13:44:02Z - 6.21.2
# 		 2021-09-07T21:33:22Z - 6.21.1
# 		 2021-08-18T08:10:17Z - 6.21.0
# 		 2021-06-28T19:15:03Z - 6.20.3
# 		 2021-06-18T12:02:56Z - 6.20.2
# 		 2021-05-14T18:07:40Z - 6.20.1
# 		 2021-05-14T09:44:33Z - 6.20.0
# 		 2021-04-18T20:59:33Z - 6.19.6
# 		 2021-03-31T10:14:02Z - 6.19.5
# 		 2021-03-09T08:20:27Z - 6.19.4
# 		 2021-03-08T22:05:14Z - 6.19.3
# 		 2021-02-19T18:55:19Z - 6.19.2
# 		 2021-01-26T14:10:58Z - 6.19.1
# 		 2021-01-21T10:30:25Z - 6.19.0
# 		 2021-01-14T18:03:49Z - 6.18.3
# 		 2021-01-14T16:08:39Z - 6.18.2
# 		 2021-01-03T10:05:50Z - 6.18.1
# 		 2020-12-08T09:29:06Z - 6.18.0
# 		 2020-11-10T09:16:17Z - 6.17.3
# 		 2020-11-09T16:28:26Z - 6.17.2
# 		 2020-11-03T09:26:36Z - 6.17.1

# %%
import psycopg2
import os
import requests 
import time
from datetime import datetime, timedelta
import pandas as pd
from scipy import stats
import numpy as np
np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
def connectDB():
    f = open('/home/elieziosoares/psql_pwd.txt', "r")
    pwd = f.readline().replace('\n','')
    
    return psycopg2.connect(user = "postgres",
                              password = pwd,
                              host = "127.0.0.1",
                              port = "5432",
                              database = "Causal_CI_Quality_v3")

# %%
def mineTags(project):
    url = 'https://api.github.com/repos/{}/git/refs/tags'.format(project)
    tags = requestAPI(url)
    
    if tags is None:
        return
    
    for tag in tags:
        try:
            ref = tag['ref']
            node = tag['node_id']
            url = tag['url']
            sha = tag['object']['sha']
            obj_type = tag['object']['type']
            obj_url = tag['object']['url']
            date = requestAPI(obj_url)
            
            if obj_type == 'tag':
                date = date['tagger']['date']
            else:
                date = date['committer']['date']
            
            storeTag(project,node,ref,url,sha,obj_type,obj_url,date)
            print('\t\t {} - {}'.format(date,ref))
        
        except Exception as e:
            print('\n\n==============================================================')
            print('Error while processing storeTag >>> Exception: {}'.format(e))
            print(e)
            print('Project: {}    Commit - {}\n\n'.format(project, obj_url))

# %%
def mineReleases(project):
    url = 'https://api.github.com/repos/{}/releases'.format(project)
    releases = requestAPI(url)
    
    if releases is None:
        return
    
    for release in releases:
        try:
            ref = release['tag_name']
            node = release['node_id']
            url = release['url']
            body = release['body']
            date = release['created_at']
            
            storeRelease(project,node,ref,url,date,body)
            print('\t\t {} - {}'.format(date,ref))
        
        except Exception as e:
            print('\n\n==============================================================')
            print('Error while processing storeRelease >>> Exception: {}'.format(e)) 
            print('Project: {}    Commit - {}\n\n'.format(project, url))

# %%
tokens =['token 80665cc2fa2fcf9f6368ac32014eda5bf5083bd3', 'token 1f3a6e7d066f937c163900db140e4506a2f3dd87', 'token 1f5163feb5b40cf70542f3a4360b957d9d6a668a']
i_token =0


def requestAPI(URL):
    # api-endpoint 
    global i_token
    
    if (len(tokens)-1) > i_token:
        i_token += 1
    else:
        i_token = 0
        
    r = requests.get(url = URL, headers={'Authorization': tokens[i_token],'Accept':'application/vnd.github.v3+json'}).json()
    #print(r)
    if len(r) > 0:
        try:
            #print('keys: {}'.format(r.keys()))
            
            if isinstance(r, dict) and 'message' in r.keys():
                #print('{} -- {}'.format(datetime.now().strftime("%H:%M:%S"),r['message']))
                if 'API rate limit exceeded' in r['message']:
                    time.sleep(600)
                    requestAPI(URL)
                elif 'Not Found' in r['message']:
                    return None
                else:
                    return r

            return r
        except Exception as e:
            print('\n Erro no request get: {}'.format(e))
            print(r)
    else:
        #print('-----')
        #print(r)
        return None

# %%
def getProjects():
    #query = """select repo_name from projects
    #        where qtd_stars >= 100 and forked is false and size  > 10000
    #        and (ci_service is null or (ci_service like 'Travis CI' and analysis_point is not null))
    #        and prs_mined is false
    #        ORDER BY repo_name """
    
    query = """select repo_name from projects WHERE rq1_included is true and 
    repo_name in('AutoSpotting/AutoSpotting','docker-archive/deploykit','gitscrum-ce/laravel-gitscrum','mdbootstrap/mdb-ui-kit','openmediavault/openmediavault','printfcoder/stack-rpc-tutorials','SimpleMobileTools/Simple-Gallery')
    ORDER BY repo_name;"""
    
    connection = connectDB()
    cursor = connection.cursor()
    cursor.execute(query)
    result = cursor.fetchall()
    connection.close()
    return result

# %%
def storeTag(repo_name,node_id,tag_ref,url,sha,object_type,object_url,object_date):
    connection = connectDB()
    cursor = connection.cursor()
    
    query = """INSERT INTO tag(
    repo_name,node_id,tag_ref,url,sha,object_type,object_url,object_date)
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"""
    
    cursor.execute(query, [repo_name,node_id,tag_ref,url,sha,object_type,object_url,object_date])
    connection.commit()
    
    cursor.close()
    connection.close()

# %%
def storeRelease(repo_name,node_id,tag_ref,url,created_at,body):
    connection = connectDB()
    cursor = connection.cursor()
    
    query = """INSERT INTO releases(repo_name,node_id,tag_ref,url,created_at,body)
    VALUES (%s,%s,%s,%s,%s,%s)"""
    
    cursor.execute(query, [repo_name,node_id,tag_ref,url,created_at,body])
    connection.commit()
    
    cursor.close()
    connection.close()
